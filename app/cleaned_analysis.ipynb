# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/cleaned_job_postings.csv")

# %%
df.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Machine Learning Engineer
# 2               Data Analyst
# 3             Data Scientist
# 4  Machine Learning Engineer
#
#                                               Skills  \
# 0  Statistics,Machine Learning,Data Wrangling,Com...
# 1  Machine Learning,Software Engineering,Data Str...
# 2  Data Analysis,Data Visualization,SQL,Spreadshe...
# 3  Deep Learning,Natural Language Processing,Big ...
# 4  Computer Vision,Reinforcement Learning,Distrib...
#
#                                                Tools         Languages
# 0          Pandas,NumPy,Scikit-learn,Jupyter,Tableau      Python,SQL,R
# 1           TensorFlow,PyTorch,Docker,Kubernetes,Git   Python,C++,Java
# 2  Excel,Tableau,Power BI,SQL Server,Google Analy...      SQL,Python,R
# 3                     Spark,Hadoop,Keras,Jupyter,AWS  Python,Scala,SQL
# 4                      OpenCV,DVC,MLflow,Airflow,GCP         Python,Go
